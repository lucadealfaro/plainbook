# %% [markdown]
# # This is the title

# %%
sum = 0
for i in range(101):
    sum += i

print(sum)
# Out:
# 5050

# %%
sum_of_squares = 0

for i in range(21):
    sum_of_squares += i**2

print(sum_of_squares)
# Out:
# 2870

# %%
import math

print(math.sqrt(5))
# Out:
# 2.23606797749979
