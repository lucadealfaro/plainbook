# %% [markdown]
# # This is the title

# %%
total = sum(range(101))
print(total)
# Out:
# 5050

# %%
total_of_squares = sum(i**2 for i in range(21))

print(total_of_squares)
# Out:
# 2870

# %%
import math

print(math.sqrt(5))
# Out:
# 2.23606797749979
